# %%
import pandas as pd

# %%
universities = ["AU", "AAU", "CBS", "DTU", "ITU", "KU", "RUC", "SDU"]
years = ["08A", "13A", "18", "22-1"]

# %%
attempt_one = pd.read_csv("AAU_virk_08A.csv", sep=";", index_col=False)

# %%
attempt_one["University"] = "AAU"

# %%
# Out:
#   Finanslov    År  I alt omsætning (mio kr)  Tilskud i alt UBST  \
# 0         R  2002                    1484.3              1049.3
# 1         R  2003                    1467.8              1083.3
# 2         R  2004                    1546.6              1102.4
# 3         R  2005                    1549.2              1103.9
# 4         R  2006                    1555.3              1106.3
# 5         B  2007                    1633.0              1109.9
# 6         F  2008                    1739.8              1219.0
# 7      BO 1  2009                    1774.4              1243.6
# 8      BO 2  2010                    1760.1              1218.9
# 9      BO 3  2011                    1776.0              1234.8
#
#    Uddannelsestilskud fra UBST  Heltidsuddannelse  Deltidsuddannelse  \
# 0                        550.7              527.8               19.5
# 1                        541.7              526.1               12.2
# ...
